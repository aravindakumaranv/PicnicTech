# %%
import pandas as pd
import gurobipy as gp
import math
import pickle as pkl
from datetime import datetime, timedelta
import copy

# %%
product_type = "frozen"
num_time_periods = 365

# %%
article_data = pd.read_csv("./data/article.csv")
article_data = article_data[(article_data['TEMPERATURE_ZONE'] == product_type)]
#article_data = article_data.head(465)

# %%
# constants definitions
if(product_type=="frozen"):
    warehouse_volume = 20
if(product_type=="chilled"):
    warehouse_volume = 180
if(product_type=="ambient"):
    warehouse_volume = 900
buffer_cost = 25
default_max_order = 10000
max_order_exceed_multiplier = 1.5

# %%
def createParameterMatrix(data, columns):
    parameters = []
    for column in columns:
        parameters.append(data[column].to_list())
    parameters = list(map(list, zip(*parameters)))
    return parameters

# %%
articles = article_data['ARTICLE_ID'].to_list()

parameters = createParameterMatrix(
    article_data,
    [
        'TEMPERATURE_ZONE',
        'VOLUME_M3_PER_CU',
        'MEAN_SHELF_LIFE',
        'CU_PER_TU',
        'ORDERING_COST_FIXED',
        'ORDERING_COST_PER_TU',
        'CLEARING_COST_PER_CU',
        'MINIMUM_ORDER_QUANTITY_TU',
        'MAXIMUM_ORDER_QUANTITY_TU'
    ]
)
parameters_dict = dict(zip(articles, parameters))

# %%
items, category, volume_per_cu, shelf_life, cu_per_tu, ordering_cost_fixed, ordering_cost_per_tu, clearing_cost_per_cu, minimum_order_quantity_tu, maximum_order_quantity_tu = gp.multidict(parameters_dict)

# %%
forecast_data = pd.read_csv('./data/sales_'+str(num_time_periods)+'.csv')
forecast_data = forecast_data[forecast_data['ARTICLE_ID'].isin(articles)]

# %%
# Create a new dataframe with all dates
all_dates_df = pd.DataFrame({'DATE': pd.date_range(start=min(forecast_data['DATE']), end=max(forecast_data['DATE']), freq='D')}).astype(str)
# Group the original dataframe by item
grouped = forecast_data.groupby('ARTICLE_ID')

# Initialize an empty list to store the new dataframes
new_dfs = []

# Loop over each group
for item, group_df in grouped:
    
    group_df['DATE'] = pd.to_datetime(group_df['DATE']).astype(str)

    # Merge the group dataframe with the all_dates dataframe
    merged_df = pd.merge(all_dates_df, group_df, on='DATE', how='outer')
    merged_df['ARTICLE_ID'] = item
    
    # Fill in missing values
    merged_df['PICKING_QUANTITY_CU'] = merged_df['PICKING_QUANTITY_CU'].fillna(0)
    
    # Sort by date and append to the list
    new_dfs.append(merged_df.sort_values('DATE'))
    
# Concatenate all new dataframes into a single dataframe
forecast_data = pd.concat(new_dfs)
time_periods = forecast_data['DATE'].unique()

time_indexes = [*range(len(time_periods))]
date_to_index = {time_periods[i]:[*range(len(time_periods))][i] for i in time_indexes}
index_to_date = {[*range(len(time_periods))][i]:time_periods[i] for i in time_indexes}

demand = forecast_data.groupby('ARTICLE_ID').apply(lambda x: dict(zip(x['DATE'], x['PICKING_QUANTITY_CU']))).to_dict()
for item in demand.keys():
    demand[item] = dict((date_to_index[key], value) for (key, value) in demand[item].items())

# %%
initial_inventory = {}
for item in demand.keys():
    initial_inventory[item] = 0
    for t in time_indexes:
        if(t%7!=6):
            if(sum(list(demand[item].values())[:t+1]) > maximum_order_quantity_tu[item] * cu_per_tu[item] * ((t+1)-((t+1)//7))):
                initial_inventory[item] += sum(list(demand[item].values())[:t+1]) - (maximum_order_quantity_tu[item] * cu_per_tu[item] * ((t+1)-((t+1)//7)))

# %%
def exact_solver(demand,a,b):
# model object
    m = gp.Model()

    # decision variables
    # Xit
    orders = m.addVars(items, time_indexes, vtype=gp.GRB.INTEGER, lb=0)
    # Yit
    ordered_boolean = m.addVars(items, time_indexes, vtype=gp.GRB.BINARY, lb=0)
    # Sit
    storage_used = m.addVars(items, time_indexes, vtype=gp.GRB.INTEGER, lb=0)
    # Zt
    buffer_storage_used = m.addVars(time_indexes, vtype=gp.GRB.INTEGER, lb=0)
    # Dit
    clearances = m.addVars(items, time_indexes, vtype=gp.GRB.INTEGER, lb=0)
    # Qit
    item_max_order_exceeded = m.addVars(items, time_indexes, vtype=gp.GRB.INTEGER, lb=0)

    # objective function
    ordering_cost_per_tu_objective = gp.quicksum(ordering_cost_per_tu[item] * orders[item, t] for item in items for t in time_indexes)
    ordering_cost_fixed_objective = gp.quicksum(ordering_cost_fixed[item] * ordered_boolean[item, t] for item in items for t in time_indexes)
    buffer_storage_objective = gp.quicksum(buffer_cost * buffer_storage_used[t] for t in time_indexes)
    clearance_objective = gp.quicksum(clearing_cost_per_cu[item] * clearances[item, t] for item in items for t in time_indexes)
    max_order_objective = gp.quicksum(ordering_cost_per_tu[item] * max_order_exceed_multiplier * item_max_order_exceeded[item, t] for item in items for t in time_indexes)

    m.setObjective(ordering_cost_per_tu_objective + ordering_cost_fixed_objective + buffer_storage_objective + clearance_objective + max_order_objective, sense=gp.GRB.MINIMIZE)

    # constraints
    # demand satisfaction
    for item in demand.keys():
        for t in time_indexes:
            if(t==0):
                m.addConstr(
                    (orders[item, t] * cu_per_tu[item])
                    # +
                    # initial_inventory[item]
                    -
                    storage_used[item, t]
                    -
                    clearances[item, t]
                    >=
                    demand[item][t]
                    
                )
            else:
                m.addConstr(
                    (orders[item, t] * cu_per_tu[item])
                    +
                    storage_used[item, t-1]
                    -
                    storage_used[item, t]
                    -
                    clearances[item, t]
                    >=
                    demand[item][t]
                )

    # inventory volume constraint
    for t in time_indexes:
        if(t==0):
            m.addConstr(
                gp.quicksum(
                    volume_per_cu[item] * 
                    (
                        (cu_per_tu[item] * orders[item, t])
                    )
                    for item in items
                )
                <=
                warehouse_volume
                +
                buffer_storage_used[t]
            )
        else:
            m.addConstr(
                gp.quicksum(
                    volume_per_cu[item] *
                    (
                        storage_used[item,t-1]
                        +
                        (cu_per_tu[item] * orders[item, t])
                    )
                    for item in items
                )
                <=
                warehouse_volume
                +
                buffer_storage_used[t]
            )

    # min/max constraints (linking too)
    for item in demand.keys():
        for t in time_indexes:
            m.addConstr(
                orders[item, t]
                >=
                minimum_order_quantity_tu[item] * ordered_boolean[item, t]
            )
            if((not math.isnan(maximum_order_quantity_tu[item])) and t%7!=6):
                m.addConstr(orders[item, t] <= (maximum_order_quantity_tu[item] * ordered_boolean[item, t]) + item_max_order_exceeded[item, t])

    for item in demand.keys():
        for t in time_indexes:
            life = shelf_life[item]
            if(t >= life):
                m.addConstr(
                    clearances[item, t]
                    >=
                    gp.quicksum(
                        cu_per_tu[item] * orders[item, t1] for t1 in time_indexes[:t-life]
                    )
                    -
                    gp.quicksum(
                        demand[item][t1] for t1 in time_indexes[:t]
                    )
                    -
                    gp.quicksum(
                        clearances[item, t1] for t1 in time_indexes[:t-1]
                    )
                )

    # Making the decision variables null for all week other than one
    for item in demand.keys():
        for t in time_indexes:
            if (t<a or t >b):
                m.addConstr(orders[item,t]==0)
                m.addConstr(ordered_boolean[item,t]==0)


    # sunday constraint
    for item in demand.keys():
        for t in time_indexes:
            if(t%7==6):
                m.addConstr(orders[item, t] == 0)
                m.addConstr(ordered_boolean[item, t] == 0)
                m.addConstr(clearances[item, t] == 0)
                m.addConstr(storage_used[item, t] == storage_used[item, t-1])

    m.setParam('TimeLimit', 200)
    m.optimize()
    output=m.objVal
    return output

# %%
#demand

# %%
def data_set_modifier(demand_reset,a,b):
    for xyz in demand_reset:
        abc=demand_reset[xyz]
        for d in abc:
             if d < a or d > b:
                 abc[d]=0

    #print(demand_reset)
    output = exact_solver(demand_reset,a,b)
    return output

   
Fin_output=0
num_days=362
num_weeks=num_days//7
week_indices=[i*7 for i in range(num_weeks)]

for week_start in week_indices:
    week_end=week_start+6
    modified_dataset = copy.deepcopy(demand)
    output=data_set_modifier(modified_dataset,week_start,week_end)
    Fin_output += output
# Out:
# Set parameter TimeLimit to value 200
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 719873 rows, 760848 columns and 1581700 nonzeros
# Model fingerprint: 0xf2be46da
# Variable types: 0 continuous, 760848 integer (152097 binary)
# Coefficient statistics:
#   Matrix range     [2e-04, 4e+02]
#   Objective range  [1e-01, 7e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 109909.55000
# Presolve removed 717453 rows and 756716 columns
# Presolve time: 1.47s
# Presolved: 2420 rows, 4132 columns, 9366 nonzeros
# Found heuristic solution: objective 89892.750000
# Variable types: 0 continuous, 4132 integer (576 binary)
# Found heuristic solution: objective 85343.250000
#
# Root relaxation: objective 6.983828e+04, 3234 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 69838.2782    0 1098 85343.2500 69838.2782  18.2%     -    1s
# H    0     0                    77364.100000 69838.2782  9.73%     -    1s
# H    0     0                    76660.150000 69838.2782  8.90%     -    1s
# H    0     0                    76517.350000 69838.2782  8.73%     -    1s
# H    0     0                    76453.400000 69838.2782  8.65%     -    1s
#      0     0 70286.9332    0  873 76453.4000 70286.9332  8.07%     -    1s
# H    0     0                    76343.150000 70286.9332  7.93%     -    1s
# H    0     0                    75259.300000 70317.6774  6.57%     -    1s
#      0     0 70317.6774    0  843 75259.3000 70317.6774  6.57%     -    1s
#      0     0 70318.1891    0  849 75259.3000 70318.1891  6.57%     -    1s
#      0     0 70318.1907    0  848 75259.3000 70318.1907  6.57%     -    1s
#      0     0 70691.5061    0  802 75259.3000 70691.5061  6.07%     -    1s
# H    0     0                    75256.100000 70691.5061  6.07%     -    1s
# H    0     0                    75247.900000 70691.5061  6.06%     -    1s
# H    0     0                    74500.050000 70730.2774  5.06%     -    1s
#      0     0 70730.2774    0  777 74500.0500 70730.2774  5.06%     -    1s
#      0     0 70730.8320    0  804 74500.0500 70730.8320  5.06%     -    1s
#  21301 11593 72909.5378  262   63 72910.1500 72880.7927  0.04%  15.0   55s
#  24264 13514 72910.0018  204   82 72910.1500 72881.9628  0.04%  15.8   60s
#  27738 15714 72909.7490   61  123 72910.1500 72883.2879  0.04%  16.8   66s
#  29966 15507 72909.9211  121  616 72910.1500 72883.3054  0.04%  17.7   76s
#  30088 15569 72910.1244   47  176 72910.1500 72902.6609  0.01%  17.9   80s
#
# Cutting planes:
#   Learned: 7
#   Gomory: 187
#   Implied bound: 19
#   MIR: 1102
#   StrongCG: 47
#   Flow cover: 52
#   Inf proof: 2
#   Zero half: 212
#   Mod-K: 31
#   RLT: 6
#
# Explored 30395 nodes (553265 simplex iterations) in 81.16 seconds (41.77 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 72910.2 72911.9 72912.5 ... 72980.2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.291015000000e+04, best bound 7.290294200117e+04, gap 0.0099%
# Set parameter TimeLimit to value 200
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 719873 rows, 760848 columns and 1581700 nonzeros
# Model fingerprint: 0x979cdf58
# Variable types: 0 continuous, 760848 integer (152097 binary)
# Coefficient statistics:
#   Matrix range     [2e-04, 4e+02]
#   Objective range  [1e-01, 7e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 114926.00000
# Presolve removed 717423 rows and 756668 columns
# Presolve time: 1.14s
# Presolved: 2450 rows, 4180 columns, 9476 nonzeros
# Found heuristic solution: objective 92981.000000
# Variable types: 0 continuous, 4180 integer (600 binary)
# Found heuristic solution: objective 88756.950000
#
# Root relaxation: objective 7.361740e+04, 3219 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 73617.3996    0 1117 88756.9500 73617.3996  17.1%     -    1s
# H    0     0                    81651.850000 73617.3996  9.84%     -    1s
# H    0     0                    80482.400000 73617.3996  8.53%     -    1s
# H    0     0                    80450.050000 73617.3996  8.49%     -    1s
# H    0     0                    80420.600000 73617.3996  8.46%     -    1s
# H    0     0                    79996.550000 73650.3923  7.93%     -    1s
#      0     0 74161.1753    0  920 79996.5500 74161.1753  7.29%     -    1s
# H    0     0                    79986.050000 74161.1753  7.28%     -    1s
# H    0     0                    79611.650000 74161.1753  6.85%     -    1s
#      0     0 74207.2370    0  906 79611.6500 74207.2370  6.79%     -    1s
#      0     0 74207.6058    0  900 79611.6500 74207.6058  6.79%     -    1s
#      0     0 74563.3233    0  763 79611.6500 74563.3233  6.34%     -    1s
# H    0     0                    79477.300000 74563.3233  6.18%     -    1s
# H    0     0                    78440.750000 74699.7816  4.77%     -    1s
# H    0     0                    78178.550000 74699.7816  4.45%     -    1s
#      0     0 74699.7816    0  751 78178.5500 74699.7816  4.45%     -    1s
#      0     0 74700.6587    0  764 78178.5500 74700.6587  4.45%     -    1s
#      0     0 74700.7559    0  766 78178.5500 74700.7559  4.45%     -    1s
#      0     0 75031.4708    0  859 78178.5500 75031.4708  4.03%     -    1s
#      0     0 75126.7117    0  839 78178.5500 75126.7117  3.90%     -    1s
#      0     0 75127.0147    0  839 78178.5500 75127.0147  3.90%     -    1s
#      0     0 75214.3859    0  703 78178.5500 75214.3859  3.79%     -    1s
# H    0     0                    78114.850000 75214.3859  3.71%     -    1s
#      0     0 75242.0141    0  724 78114.8500 75242.0141  3.68%     -    1s
#      0     0 75244.5100    0  742 78114.8500 75244.5100  3.67%     -    1s
work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 76646.6 76647.3 76647.4 ... 76655
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.664660000000e+04, best bound 7.663995783898e+04, gap 0.0087%
# Set parameter TimeLimit to value 200
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 719873 rows, 760848 columns and 1581700 nonzeros
# Model fingerprint: 0x1004d6f5
# Variable types: 0 continuous, 760848 integer (152097 binary)
# Coefficient statistics:
#   Matrix range     [2e-04, 4e+02]
#   Objective range  [1e-01, 7e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 124843.00000
# Presolve removed 717415 rows and 756660 columns
# Presolve time: 1.22s
# Presolved: 2458 rows, 4188 columns, 9943 nonzeros
# Found heuristic solution: objective 101054.50000
# Variable types: 0 continuous, 4188 integer (560 binary)
# Found heuristic solution: objective 97530.600000
#
# Root relaxation: objective 8.073286e+04, 3366 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 80732.8628    0 1179 97530.6000 80732.8628  17.2%     -    1s
# H    0     0                    89380.350000 80732.8628  9.67%     -    1s
# H    0     0                    88087.850000 80732.8628  8.35%     -    1s
# H    0     0                    87950.400000 80732.8628  8.21%     -    1s
#      0     0 81096.8361    0  962 87950.4000 81096.8361  7.79%     -    1s
# H    0     0                    87910.550000 81096.8361  7.75%     -    1s
#      0     0 81161.7067    0  921 87910.5500 81161.7067  7.68%     -    1s
#      0     0 81509.8151    0  824 87910.5500 81509.8151  7.28%     -    1s
# H    0     0                    87905.700000 81509.8151  7.28%     -    1s
# H    0     0                    87464.300000 81509.8151  6.81%     -    1s
# H    0     0                    86071.000000 81541.4515  5.26%     -    1s
#      0     0 81541.4515    0  831 86071.0000 81541.4515  5.26%     -    1s
#      0     0 81541.6431    0  837 86071.0000 81541.6431  5.26%     -    1s
#      0     0 81839.0820    0  878 86071.0000 81839.0820  4.92%     -    1s
#      0     0 81900.2866    0  847 86071.0000 81900.2866  4.85%     -    1s
#      0     0 81900.4659    0  837 86071.0000 81900.4659  4.85%     -    1s
#      0     0 82037.3360    0  765 86071.0000 82037.3360  4.69%     -    1s
# H    0     0                    86034.600000 82037.3360  4.65%     -    1s
#      0     0 82043.2427    0  740 86034.6000 82043.2427  4.64%     -    1s
#      0     0 82043.8056    0  752 86034.6000 82043.8056  4.64%     -    1s
#      0     0 82139.7947    0  665 86034.6000 82139.7947  4.53%     -    1s
# H    0     0                    86013.600000 82139.7947  4.50%     -    2s
# H    0     0                    85367.550000 82139.7947  3.78%     -    2s
# H    0     0                    84848.000000 82139.7947  3.19%     -    2s
#      0     0 82141.9226    0  676 84848.0000 82141.9226  3.19%     -    2s
#      0     0 82141.9604    0  678 84848.0000 82141.9604  3.19%     -    2s
#      0     0 82170.5562    0  642 84848.0000 82170.5562  3.16%     -    2s
# H    0     0                    84845.100000 82170.5562  3.15%     -    2s
#      0     0 82184.0202    0  629 84845.1000 82184.0202  3.14%     -    2s
#      0     0 82184.0540    0  634 84845.1000 82184.0540  3.14%     -    2s
#      0     0 82189.6619    0  620 84845.1000 82189.6619  3.13%     -    2s
# H    0     0                    84445.000000 82189.6619  2.67%     -    2s
#      0     0 82189.7544    0  618 84445.0000 82189.7544  2.67%     -    2s
#      0     0 82189.9262    0  629 84445.0000 82189.9262  2.67%     -    2s
# H30995 13019                    83779.850000 83761.5225  0.02%  16.1  112s
#  31657 13713 83771.8948  103  139 83779.8500 83761.6198  0.02%  16.1  117s
#  32266 14305 83773.2706  159   98 83779.8500 83761.6198  0.02%  16.3  120s
#  34095 15386 83778.0062   97  134 83779.8500 83763.0498  0.02%  16.4  125s
# H35786 14963                    83779.700000 83763.7301  0.02%  16.4  127s
# H35879 14239                    83779.550000 83763.8217  0.02%  16.4  127s
#  38133 15376 83775.6586  105  128 83779.5500 83764.3380  0.02%  16.3  131s
#  40553 16358 83777.6150  121  102 83779.5500 83764.5388  0.02%  16.4  135s
#  44495 18330 83772.9039   93   63 83779.5500 83764.9327  0.02%  16.3  142s
#  47331 19144 83766.9233   87   97 83779.5500 83765.0603  0.02%  16.1  146s
#  49893 19529 83777.6513  195   76 83779.5500 83765.1261  0.02%  16.0  151s
# H49924 18665                    83779.400000 83765.1261  0.02%  16.0  151s
#  50033 19262 83778.3843  216   74 83779.4000 83765.1354  0.02%  16.0  159s
#  50873 20062 83773.9140   99   93 83779.4000 83765.1767  0.02%  16.0  165s
#  52297 20617 83773.0738   97   63 83779.4000 83765.2138  0.02%  15.9  170s
#  53678 20890 83775.3674  107   91 83779.4000 83765.2368  0.02%  15.9  175s
#  54701 21340 83777.9883  116   82 83779.4000 83765.2677  0.02%  16.0  184s
#  55831 22427 83779.1788  145  119 83779.4000 83765.2926  0.02%  15.9  189s
#  57804 22976 83770.1276  106   87 83779.4000 83765.3537  0.02%  15.7  194s
#  59368 23453 83773.7463   95   59 83779.4000 83765.3827  0.02%  15.6  200s
#
# Cutting planes:
#   Learned: 13
#   Gomory: 243
#   Implied bound: 25
#   MIR: 1237
#   StrongCG: 47
#   Flow cover: 66
#   Inf proof: 1
#   Zero half: 246
#   Mod-K: 31
#   RLT: 8
#   Relax-and-lift: 1
#
# Explored 60588 nodes (948585 simplex iterations) in 202.23 seconds (65.91 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 83779.4 83779.6 83779.7 ... 83798.3
#
# Time limit reached
# Best objective 8.377940000000e+04, best bound 8.376540028332e+04, gap 0.0167%
# Set parameter TimeLimit to value 200
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 719873 rows, 760848 columns and 1581700 nonzeros
# Model fingerprint: 0x371fe302
# Variable types: 0 continuous, 760848 integer (152097 binary)
# Coefficient statistics:
#   Matrix range     [2e-04, 4e+02]
#   Objective range  [1e-01, 7e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Presolve removed 717394 rows and 756636 columns
# Presolve time: 1.65s
# Presolved: 2479 rows, 4212 columns, 9544 nonzeros
# Variable types: 0 continuous, 4212 integer (573 binary)
# Found heuristic solution: objective 105381.35000
# Found heuristic solution: objective 95962.050000
#
# Root relaxation: objective 8.490590e+04, 3375 iterations, 0.02 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 84905.9031    0 1205 95962.0500 84905.9031  11.5%     -    2s
# H    0     0                    95872.300000 84905.9031  11.4%     -    2s
#      0     0 85258.4583    0  868 95872.3000 85258.4583  11.1%     -    2s
# H    0     0                    91103.800000 85258.4583  6.42%     -    2s
# H    0     0                    90670.450000 85258.4583  5.97%     -    2s
#      0     0 85415.3326    0  919 90670.4500 85415.3326  5.80%     -    2s
#      0     0 85415.7189    0  931 90670.4500 85415.7189  5.80%     -    2s
#      0     0 85706.1844    0  805 90670.4500 85706.1844  5.48%     -    2s
binary)
# Coefficient statistics:
#   Matrix range     [2e-04, 4e+02]
#   Objective range  [1e-01, 7e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 140054.35000
# Presolve removed 717389 rows and 756649 columns
# Presolve time: 1.75s
# Presolved: 2484 rows, 4199 columns, 9979 nonzeros
# Found heuristic solution: objective 113393.70000
# Variable types: 0 continuous, 4199 integer (558 binary)
# Found heuristic solution: objective 108127.55000
#
# Root relaxation: objective 9.066119e+04, 3433 iterations, 0.03 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 90661.1888    0 1283 108127.550 90661.1888  16.2%     -    2s
# H    0     0                    99921.150000 90661.1888  9.27%     -    2s
# H    0     0                    98561.250000 90661.1888  8.02%     -    2s
# H    0     0                    98344.950000 90661.1888  7.81%     -    2s
# H    0     0                    96822.000000 91142.7397  5.87%     -    2s
#      0     0 91142.7397    0  953 96822.0000 91142.7397  5.87%     -    2s
# H    0     0                    96558.600000 91142.7397  5.61%     -    2s
#      0     0 91236.1633    0  999 96558.6000 91236.1633  5.51%     -    2s
#      0     0 91236.4140    0 1001 96558.6000 91236.4140  5.51%     -    2s
#      0     0 91236.7788    0 1001 96558.6000 91236.7788  5.51%     -    2s
#      0     0 91535.9920    0  841 96558.6000 91535.9920  5.20%     -    2s
# H    0     0                    96506.800000 91535.9920  5.15%     -    2s
# H    0     0                    96436.550000 91563.7619  5.05%     -    2s
#      0     0 91563.7619    0  818 96436.5500 91563.7619  5.05%     -    2s
#      0     0 91563.9090    0  828 96436.5500 91563.9090  5.05%     -    2s
#      0     0 91862.8573    0  782 96436.5500 91862.8573  4.74%     -    2s
# H    0     0                    95460.200000 91862.8573  3.77%     -    2s
# H    0     0                    95153.700000 91862.8573  3.46%     -    3s
#      0     0 91913.9204    0  765 95153.7000 91913.9204  3.40%     -    3s
#      0     0 91914.1399    0  767 95153.7000 91914.1399  3.40%     -    3s
#      0     0 91986.0017    0  752 95153.7000 91986.0017  3.33%     -    3s
#      0     0 91995.1452    0  734 95153.7000 91995.1452  3.32%     -    3s
#      0     0 91995.3826    0  733 95153.7000 91995.3826  3.32%     -    3s
#      0     0 92075.0087    0  658 95153.7000 92075.0087  3.24%     -    3s
#      0     0 92076.2373    0  656 95153.7000 92076.2373  3.23%     -    3s
#      0     0 92089.6138    0  639 95153.7000 92089.6138  3.22%     -    3s
#      0     0 92089.6138    0  635 95153.7000 92089.6138  3.22%     -    4s
# H    0     0                    94300.250000 92089.6138  2.34%     -    4s
# H    0     0                    94077.900000 92089.6138  2.11%     -    5s
#      0     2 92089.6138    0  634 94077.9000 92089.6138  2.11%     -    6s
# H  279   283                    94042.000000 92097.9711  2.07%   1.8    8s
# H  281   283                    94038.950000 92097.9711  2.06%   1.8    8s
# H 1053  1058                    94034.750000 92097.9711  2.06%   1.3   12s
# H 1054  1058                    94034.000000 92097.9711  2.06%   1.3   12s
#   4186  4417 93453.4040  718  453 94034.0000 92097.9711  2.06%   1.2   15s
# H 5171  5172                    94033.700000 92097.9711  2.06%   1.2   17s
# H 5178  4672                    94032.800000 92113.0570  2.04%   1.2   18s
#   5187  4678 93072.0261  238  464 94032.8000 93072.0261  1.02%   1.2   20s
# H 5191  4447                    93982.150000 93075.8042  0.96%   1.2   20s
#  30384 19062 93851.1419   72   45 93855.5000 93836.7745  0.02%  11.1  190s
#  30565 19229 93849.4113   64  209 93855.5000 93837.9689  0.02%  11.4  195s
#  30906 19350 93848.1951   83  167 93855.5000 93837.9689  0.02%  11.6  200s
#
# Cutting planes:
#   Learned: 23
#   Gomory: 200
#   Implied bound: 16
#   MIR: 1226
#   StrongCG: 51
#   Flow cover: 92
#   Inf proof: 1
#   Zero half: 243
#   Mod-K: 33
#   RLT: 4
#
# Explored 30941 nodes (366051 simplex iterations) in 202.03 seconds (37.13 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 93855.5 93855.8 93856.1 ... 94032.8
#
# Time limit reached
# Best objective 9.385550000000e+04, best bound 9.383796886412e+04, gap 0.0187%
# Set parameter TimeLimit to value 200
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 719873 rows, 760848 columns and 1581700 nonzeros
# Model fingerprint: 0x63088a0a
# Variable types: 0 continuous, 760848 integer (152097 binary)
# Coefficient statistics:
#   Matrix range     [2e-04, 4e+02]
#   Objective range  [1e-01, 7e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 128604.50000
# Presolve removed 717413 rows and 756677 columns
# Presolve time: 1.71s
# Presolved: 2460 rows, 4171 columns, 9459 nonzeros
# Found heuristic solution: objective 104073.35000
# Variable types: 0 continuous, 4171 integer (588 binary)
# Found heuristic solution: objective 98494.600000
#
# Root relaxation: objective 8.205118e+04, 3351 iterations, 0.03 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 82051.1815    0 1223 98494.6000 82051.1815  16.7%     -    2s
# H    0     0                    92018.000000 82051.1815  10.8%     -    2s
# H    0     0                    90310.650000 82051.1815  9.15%     -    2s
# H    0     0                    90012.750000 82051.1815  8.84%     -    2s
#      0     0 82564.2132    0 1005 90012.7500 82564.2132  8.27%     -    2s
#      0     0 82635.9973    0  992 90012.7500 82635.9973  8.20%     -    2s
#      0     0 82636.3488    0  993 90012.7500 82636.3488  8.19%     -    2s
# H    0     0                    89790.500000 82983.4251  7.58%     -    2s
#      0     0 82993.3607    0  774 89790.5000 82993.3607  7.57%     -    2s
# H    0     0                    87652.750000 82993.3607  5.32%     -    2s
#      0     0 83053.9618    0  807 87652.7500 83053.9618  5.25%     -    2s
#      0     0 83062.2544    0  810 87652.7500 83062.2544  5.24%     -    2s
#      0     0 83062.4573    0  808 87652.7500 83062.4573  5.24%     -    2s
#      0     0 83429.2920    0  834 87652.7500 83429.2920  4.82%     -    2s
# H    0     0                    86593.700000 83429.2920  3.65%     -    2s
#      0     0 83455.5942    0  849 86593.7000 83455.5942  3.62%     -    2s
#      0     0 83479.5388    0  840 86593.7000 83479.5388  3.60%     -    2s
#      0     0 83480.2503    0  842 86593.7000 83480.2503  3.60%     -    2s
#      0     0 83607.0849    0  797 86593.7000 83607.0849  3.45%     -    3s
#      0     0 83610.0367    0  801 86593.7000 83610.0367  3.45%     -    3s
#      0     0 83610.1483    0  791 86593.7000 83610.1483  3.45%     -    3s
#      0     0 83703.0478    0  673 86593.7000 83703.0478  3.34%     -    3s
#      0     0 83705.9732    0  692 86593.7000 83705.9732  3.33%     -    3s
#      0     0 83706.0569    0  691 86593.7000 83706.0569  3.33%     -    3s
#      0     0 83746.7237    0  619 86593.7000 83746.7237  3.29%     -    3s
#      0     0 83747.5496    0  629 86593.7000 83747.5496  3.29%     -    3s
#  16292  8331 85325.1358  150  142 85327.9500 85283.6689  0.05%  11.4  117s
#  17180  8885 85327.5527  203   85 85327.9500 85283.6689  0.05%  11.4  120s
#  18419 10188     cutoff  226      85327.9500 85283.9099  0.05%  11.9  126s
#  20609 11706 85286.9932   61  187 85327.9500 85284.0174  0.05%  12.0  133s
#  21598 12730 85323.2155  124  170 85327.9500 85284.0339  0.05%  11.9  137s
#  22905 13540 85285.1033   47  156 85327.9500 85284.0830  0.05%  11.9  141s
#  25067 15376 85286.8165   60  215 85327.9500 85284.2038  0.05%  12.3  148s
#  26275 15412 85323.9867  107  131 85327.9500 85284.2265  0.05%  12.4  154s
# H26297 14545                    85326.600000 85284.2265  0.05%  12.4  154s
#  26337 15717 85324.0197  110  135 85326.6000 85284.2302  0.05%  12.4  158s
#  27848 16692 85301.9864   52  148 85326.6000 85284.2712  0.05%  12.3  162s
#  29332 15858 85314.9943   64  593 85326.6000 85284.2882  0.05%  12.4  177s
#  29344 15866 85302.7522   56   44 85326.6000 85302.7522  0.03%  12.4  180s
#  29356 15874 85306.9527   83   50 85326.6000 85306.9527  0.02%  12.4  185s
#  29373 15885 85325.6731  169   41 85326.6000 85309.2943  0.02%  12.4  190s
#  29381 15891 85309.6246   68   43 85326.6000 85309.6246  0.02%  12.4  195s
#
# Cutting planes:
#   Learned: 16
#   Gomory: 222
#   Implied bound: 27
#   MIR: 1118
#   StrongCG: 48
#   Flow cover: 67
#   Inf proof: 1
#   Zero half: 210
#   Mod-K: 38
#   RLT: 7
#   Relax-and-lift: 1
#
# Explored 29785 nodes (384675 simplex iterations) in 200.41 seconds (35.46 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 85326.6 85328 85328.3 ... 85355.6
#
# Time limit reached
# Best objective 8.532660000000e+04, best bound 8.531068969104e+04, gap 0.0186%
# Set parameter TimeLimit to value 200
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 719873 rows, 760848 columns and 1581700 nonzeros
# Model fingerprint: 0xdf4bab26
# Variable types: 0 continuous, 760848 integer (152097 binary)
# Coefficient statistics:
#   Matrix range     [2e-04, 4e+02]
#   Objective range  [1e-01, 7e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 116461.60000
# Presolve removed 717475 rows and 756752 columns
# Presolve time: 1.72s
# Presolved: 2398 rows, 4096 columns, 9287 nonzeros
# Found heuristic solution: objective 94674.450000
# Variable types: 0 continuous, 4096 integer (583 binary)
# Found heuristic solution: objective 89877.650000
#
# Root relaxation: objective 7.418361e+04, 3204 iterations, 0.02 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 74183.6135    0 1093 89877.6500 74183.6135  17.5%     -    2s
# H    0     0                    81507.650000 74183.6135  8.99%     -    2s
# H    0     0                    81329.350000 74183.6135  8.79%     -    2s
# H    0     0                    81269.400000 74183.6135  8.72%     -    2s
# H    0     0                    80810.900000 74183.6135  8.20%     -    2s
#      0     0 74711.0758    0  845 80810.9000 74711.0758  7.55%     -    2s
#      0     0 74767.9238    0  822 80810.9000 74767.9238  7.48%     -    2s
#      0     0 74768.0631    0  822 80810.9000 74768.0631  7.48%     -    2s
#      0     0 75101.8919    0  801 80810.9000 75101.8919  7.06%     -    2s
# H    0     0                    79439.450000 75101.8919  5.46%     -    2s
# H    0     0                    79365.950000 75101.8919  5.37%     -    2s
# H    0     0                    79352.400000 75132.3821  5.32%     -    2s
#      0     0 75132.3821    0  750 79352.4000 75132.3821  5.32%     -    2s
#      0     0 75132.5517    0  735 79352.4000 75132.5517  5.32%     -    2s
#      0     0 75489.4187    0  747 79352.4000 75489.4187  4.87%     -    2s
#      0     0 75522.0975    0  750 79352.4000 75522.0975  4.83%     -    2s
#      0     0 75522.9112    0  756 79352.4000 75522.9112  4.83%     -    2s
#      0     0 75707.6381    0  674 79352.4000 75707.6381  4.59%     -    2s
# H    0     0                    78615.000000 75707.6381  3.70%     -    2s
#      0     0 75711.4195    0  657 78615.0000 75711.4195  3.69%     -    2s
#      0     0 75715.0870    0  642 78615.0000 75715.0870  3.69%     -    2s
#      0     0 75715.0958    0  649 78615.0000 75715.0958  3.69%     -    2s
#      0     0 75773.9692    0  600 78615.0000 75773.9692  3.61%     -    2s
# H    0     0                    77987.700000 75773.9692  2.84%     -    3s
#      0     0 75774.5040    0  577 77987.7000 75774.5040  2.84%     -    3s
# ...
#   5568  5239 60197.4942  946  360 60218.2500 58830.5623  2.30%   5.6   25s
#   5590  5254 60012.0601   53  168 60218.2500 60012.0601  0.34%   5.6   30s
# H 5592  4992                    60210.450000 60017.6543  0.32%   5.6   30s
# H 5593  4743                    60199.450000 60035.6384  0.27%   5.6   30s
#   5616  4758 60193.1915  815  157 60199.4500 60156.3139  0.07%   5.6   35s
# H 5616  4519                    60197.650000 60156.3686  0.07%   5.6   35s
#   5637  4307 60168.7498  183   45 60197.6500 60168.7498  0.05%   7.8   40s
#   5646  4313 60180.7059  658   51 60197.6500 60180.7059  0.03%   7.8   45s
# H 5648  4099                    60196.150000 60180.7145  0.03%   7.8   47s
# H 5713  3947                    60195.850000 60181.7736  0.02%   8.9   49s
# H 5714  3752                    60195.050000 60181.7736  0.02%   8.9   49s
# H 5716  3565                    60189.350000 60181.7736  0.01%   8.9   49s
# H 5718  3388                    60189.050000 60181.7736  0.01%   8.9   50s
#   6082  3705 60186.1790   42   50 60189.0500 60181.8069  0.01%   9.1   55s
#   6769  4278 60183.7245   86   33 60189.0500 60181.8069  0.01%   9.8   60s
#   7918  5099 60183.8500  101   50 60189.0500 60181.9641  0.01%  10.4   65s
#  10004  5987 60187.4039  122   37 60189.0500 60182.1500  0.01%  10.3   71s
#  11432  6387 60186.2500  104   44 60189.0500 60182.1825  0.01%  10.1   77s
#  12135  6936 60186.2852  136   73 60189.0500 60182.3147  0.01%  10.4   80s
#  15529  7348 60182.6226   56  360 60189.0500 60182.3846  0.01%  10.3   85s
#
# Cutting planes:
#   Learned: 1
#   Gomory: 112
#   Cover: 1
#   Implied bound: 19
#   MIR: 761
#   StrongCG: 43
#   Flow cover: 16
#   Zero half: 139
#   Mod-K: 17
#   RLT: 1
#
# Explored 15537 nodes (170449 simplex iterations) in 87.26 seconds (15.83 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 60189.1 60189.4 60195.1 ... 60222.8
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.018905000000e+04, best bound 6.018345149759e+04, gap 0.0093%
# Set parameter TimeLimit to value 200
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 719873 rows, 760848 columns and 1581700 nonzeros
# Model fingerprint: 0xcc8e5113
# Variable types: 0 continuous, 760848 integer (152097 binary)
# Coefficient statistics:
#   Matrix range     [2e-04, 4e+02]
#   Objective range  [1e-01, 7e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 96515.850000
# Presolve removed 717470 rows and 756708 columns
# Presolve time: 3.44s
# Presolved: 2403 rows, 4140 columns, 9385 nonzeros
# Found heuristic solution: objective 76235.050000
# Variable types: 0 continuous, 4140 integer (691 binary)
# Found heuristic solution: objective 73550.300000
#
# Root relaxation: objective 5.855164e+04, 3046 iterations, 0.05 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 58551.6371    0  935 73550.3000 58551.6371  20.4%     -    4s
# H    0     0                    64672.250000 58551.6371  9.46%     -    4s
# H    0     0                    64403.850000 58551.6371  9.09%     -    4s
# H    0     0                    64354.850000 58551.6371  9.02%     -    4s
# H    0     0                    64306.250000 58551.6371  8.95%     -    4s
#      0     0 59348.6916    0  548 64306.2500 59348.6916  7.71%     -    4s
# H    0     0                    62907.350000 59348.6916  5.66%     -    4s
# H    0     0                    62762.050000 59348.6916  5.44%     -    4s
#      0     0 59393.4554    0  537 62762.0500 59393.4554  5.37%     -    4s
#      0     0 59783.0277    0  594 62762.0500 59783.0277  4.75%     -    4s
#      0     0 59806.6928    0  542 62762.0500 59806.6928  4.71%     -    5s
#      0     0 59806.7181    0  540 62762.0500 59806.7181  4.71%     -    5s
#      0     0 60045.8714    0  545 62762.0500 60045.8714  4.33%     -    5s
# H    0     0                    62268.450000 60045.8714  3.57%     -    5s
#      0     0 60077.8564    0  507 62268.4500 60077.8564  3.52%     -    5s
#      0     0 60090.5498    0  524 62268.4500 60090.5498  3.50%     -    5s
#      0     0 60090.5498    0  524 62268.4500 60090.5498  3.50%     -    5s
#      0     0 60192.7378    0  472 62268.4500 60192.7378  3.33%     -    5s
# H    0     0                    62110.950000 60192.7378  3.09%     -    5s
#      0     0 60250.0975    0  460 62110.9500 60250.0975  3.00%     -    6s
#      0     0 60252.4951    0  458 62110.9500 60252.4951  2.99%     -    6s
#      0     0 60254.1691    0  458 62110.9500 60254.1691  2.99%     -    6s
#      0     0 60291.7494    0  410 62110.9500 60291.7494  2.93%     -    6s
# H    0     0                    61878.050000 60291.7494  2.56%     -    7s
#      0     0 60294.8458    0  409 61878.0500 60294.8458  2.56%     -    7s
#      0     0 60294.9132    0  395 61878.0500 60294.9132  2.56%     -    7s
#      0     0 60323.6849    0  379 61878.0500 60323.6849  2.51%     -    8s
#      0     0 60341.5839    0  372 61878.0500 60341.5839  2.48%     -    8s
#      0     0 60341.6053    0  387 61878.0500 60341.6053  2.48%     -    8s
#      0     0 60349.1226    0  388 61878.0500 60349.1226  2.47%     -    8s
#      0     0 60349.1548    0  391 61878.0500 60349.1548  2.47%     -    8s
#      0     0 60355.7593    0  388 61878.0500 60355.7593  2.46%     -    8s
#      0     0 60355.7593    0  378 61878.0500 60355.7593  2.46%     -    8s
#      0     2 60355.7593    0  374 61878.0500 60355.7593  2.46%     -    9s
# H   31    36                    61876.250000 60366.9847  2.44%   6.5   10s
# H   32    36                    61827.150000 60366.9847  2.36%   6.3   10s
# H  110   116                    61817.350000 60366.9847  2.35%   3.7   11s
# H  144   151                    61807.550000 60366.9847  2.33%   4.6   12s
# H  218   223                    61792.850000 60366.9847  2.31%   3.8   15s
# H  993  1044                    61767.950000 60366.9847  2.27%   3.3   18s
work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 61746.1 61746.2 61749 ... 61827.2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.174614999389e+04, best bound 6.174174026211e+04, gap 0.0071%
# Set parameter TimeLimit to value 200
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 719873 rows, 760848 columns and 1581700 nonzeros
# Model fingerprint: 0x2ab782f1
# Variable types: 0 continuous, 760848 integer (152097 binary)
# Coefficient statistics:
#   Matrix range     [2e-04, 4e+02]
#   Objective range  [1e-01, 7e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+02]
# Found heuristic solution: objective 110204.90000
# Presolve removed 717797 rows and 757374 columns
# Presolve time: 1.62s
# Presolved: 2076 rows, 3474 columns, 8187 nonzeros
# Found heuristic solution: objective 86512.350000
# Variable types: 0 continuous, 3474 integer (501 binary)
# Found heuristic solution: objective 80946.300000
#
# Root relaxation: objective 6.741709e+04, 2713 iterations, 0.02 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 67417.0927    0  899 80946.3000 67417.0927  16.7%     -    2s
# H    0     0                    73347.500000 67417.0927  8.09%     -    2s
# H    0     0                    73127.400000 67417.0927  7.81%     -    2s
# H    0     0                    72914.550000 67417.0927  7.54%     -    2s
#      0     0 68020.4300    0  711 72914.5500 68020.4300  6.71%     -    2s
# H    0     0                    71540.200000 68020.4300  4.92%     -    2s
# H    0     0                    71264.950000 68020.4300  4.55%     -    2s
#      0     0 68029.6721    0  682 71264.9500 68029.6721  4.54%     -    2s
#      0     0 68029.8626    0  684 71264.9500 68029.8626  4.54%     -    2s
#      0     0 68381.2110    0  539 71264.9500 68381.2110  4.05%     -    2s
# H    0     0                    71190.850000 68381.2110  3.95%     -    2s
# H    0     0                    70981.950000 68430.0756  3.60%     -    2s
#      0     0 68430.0756    0  505 70981.9500 68430.0756  3.60%     -    2s
#      0     0 68437.1518    0  514 70981.9500 68437.1518  3.59%     -    2s
#      0     0 68437.5268    0  516 70981.9500 68437.5268  3.58%     -    2s
#      0     0 68675.8090    0  547 70981.9500 68675.8090  3.25%     -    2s
#      0     0 68747.2886    0  518 70981.9500 68747.2886  3.15%     -    2s
#      0     0 68747.8797    0  516 70981.9500 68747.8797  3.15%     -    2s
#      0     0 68825.7885    0  490 70981.9500 68825.7885  3.04%     -    2s
# H    0     0                    70641.000000 68828.8708  2.57%     -    3s
#      0     0 68828.8708    0  495 70641.0000 68828.8708  2.57%     -    3s
#      0     0 68828.8820    0  497 70641.0000 68828.8820  2.57%     -    3s
#      0     0 68872.6084    0  459 70641.0000 68872.6084  2.50%     -    3s
# H    0     0                    70251.450000 68872.6084  1.96%     -    3s
#      0     0 68878.1444    0  435 70251.4500 68878.1444  1.95%     -    3s
#      0     0 68878.1791    0  442 70251.4500 68878.1791  1.95%     -    3s
#      0     0 69098.0346    0  457 70251.4500 69098.0346  1.64%     -    3s
#      0     0 69114.5170    0  439 70251.4500 69114.5170  1.62%     -    3s
#      0     0 69114.7021    0  432 70251.4500 69114.7021  1.62%     -    3s
#      0     0 69202.8971    0  380 70251.4500 69202.8971  1.49%     -    3s
# H    0     0                    70161.750000 69202.8971  1.37%     -    4s
#      0     0 69203.6051    0  356 70161.7500 69203.6051  1.37%     -    4s
#      0     0 69209.7364    0  353 70161.7500 69209.7364  1.36%     -    4s
#      0     0 69209.7364    0  346 70161.7500 69209.7364  1.36%     -    4s
# H    0     0                    70138.600000 69209.7364  1.32%     -    5s
# H    0     0                    70094.950000 69209.7364  1.26%     -    8s
#      0     2 69209.7364    0  346 70094.9500 69209.7364  1.26%     -    8s
# H   69    81                    70094.350000 69212.4468  1.26%   1.5    8s
#    194   199 69298.9305   36  332 70094.3500 69212.4468  1.26%   1.2   10s
#   2530  2535 69919.6099  417  248 70094.3500 69212.4468  1.26%   1.6   16s
#   4850  5068 69399.5196  113  308 70094.3500 69212.5186  1.26%   1.8   21s
# H 5432  5409                    70090.950000 69212.5186  1.25%   1.8   22s
# H 5445  4889                    70086.450000 69744.6729  0.49%   1.8   25s
#   5488  4673 70034.6870  115  859 70086.4500 70034.6870  0.07%   2.8   30s
# H 5576  4506                    70082.950000 70040.1845  0.06%   4.0   35s
# H 5578  4283                    70077.250000 70040.1845  0.05%   4.0   35s
# H 5580  4072                    70067.700000 70040.1845  0.04%   4.0   35s
# H 5907  4287                    70065.600000 70040.1845  0.04%   4.6   39s
#   6115  4747 70053.0640   68  143 70065.6000 70040.1845  0.04%   4.8   41s
#   7727  5711 70043.3899   54   78 70065.6000 70040.3025  0.04%   6.7   46s
#   9564  6599 70056.4500  259   11 70065.6000 70040.3025  0.04%   7.7   51s
# H10211  6492                    70065.300000 70040.3025  0.04%   8.4   53s
#  10668  6728     cutoff  340      70065.3000 70040.6452  0.04%   9.3   55s
# H10823  6491                    70065.200000 70040.6452  0.04%   9.3   55s
# H10997  6253                    70065.150000 70040.6452  0.03%   9.2   55s
#  12774  7974 70059.9315  120  116 70065.1500 70041.4684  0.03%  10.4   61s
#  15301  9105 70058.8924  137   76 70065.1500 70041.8330  0.03%  10.4   66s
#  17074 10516 70060.3138  162   78 70065.1500 70041.9830  0.03%  10.4   70s
#  20290 12961 70059.0039  142  102 70065.1500 70042.1037  0.03%  10.3   76s
#  21980 14570 70044.8624   60   70 70065.1500 70042.1415  0.03%  10.6   80s
#  24184 16667 70051.6647  100  119 70065.1500 70042.2101  0.03%  10.8   86s
# H25554 16179                    70064.450000 70042.2123  0.03%  10.7   89s
# H25557 15730                    70064.000000 70042.2123  0.03%  10.7   89s
# H25581 14860                    70063.250000 70042.2123  0.03%  10.7   89s
#  25609 15851 70043.0001   44   77 70063.2500 70042.2215  0.03%  10.7   92s
#  26731 16725 70052.9384  153   37 70063.2500 70042.2432  0.03%  10.7   95s
#  28672 18349 70060.2213  297   18 70063.2500 70042.2493  0.03%  10.8  102s
#  29730 17432 70057.2421   90  346 70063.2500 70042.2493  0.03%  10.7  118s
#
# Cutting planes:
#   Learned: 19
#   Gomory: 146
#   Cover: 2
#   Implied bound: 21
#   MIR: 819
#   StrongCG: 33
#   Flow cover: 35
#   Zero half: 132
#   Mod-K: 61
#   RLT: 4
#
# Explored 29735 nodes (327886 simplex iterations) in 118.76 seconds (24.06 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 70063.3 70064 70064.5 ... 70083
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.006325000000e+04, best bound 7.005741512674e+04, gap 0.0083%

# %%
print(Fin_output)
#
# Out:
# 3580641.1499938928
